# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

file_path = '/content/drive/My Drive/complete-tv.json'

try:
    with open(file_path, 'r', encoding='utf8') as f:
        data = json.loads(f.read())
        df = pd.json_normalize(data)
        print(df)
except ValueError as e:
    print(f"ValueError: {e}")
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")
# Out:
#             id                                              title  popularity  \
# 0            1                                               プライド      70.679
# 1            2                                             Clerks     150.847
# 2            3                                        The Message      21.368
# 3            4                          The Amazing Mrs Pritchard      68.590
# 4            5                                             La Job      17.123
# ...        ...                                                ...         ...
# 176844  260182        Nom d'un chien ! Le plus beau c'est le mien       0.680
# 176845  260183  Looney Tunes Presents: Sports Talk With Bugs B...       1.400
# 176846  260184                                              大汉的天空       1.021
# 176847  260185                                   Schiphol Airport       1.400
# 176848  260186                                       우당탕탕 하찮은 동창회       0.600
#
#                                                  overview  \
# 0       Haru Satonaka is the captain of an ice-hockey ...
# 1       The continuing adventures of store clerks Dant...
# 2       The Message was a surreal comedy series which ...
# 3       Supermarket manager Ros Pritchard decides to s...
# 4       La Job is a French Canadian comedy television ...
# ...                                                   ...
# 176844
# 176845  Bugs Bunny meets his favorite athletes to lear...
# 176846
# 176847
# 176848  "The crazy reunion of friends who haven't seen...
#
#                      genres language origin_country  \
# 0                   [Drama]       ja           [JP]
# 1       [Animation, Comedy]       en           [US]
# 2                  [Comedy]       en           [GB]
# 3                   [Drama]       en           [GB]
# 4                  [Comedy]       fr           [CA]
# ...                     ...      ...            ...
# 176844    [Reality, Family]       fr           [BE]
# 176845    [Animation, Talk]       en           [US]
# 176846        [Documentary]       zh           [CN]
# 176847                 None       nl           [NL]
# 176848                 None       ko           [KR]
#
#                              keywords  \
# 0       [sports, ice hockey, romance]
# 1                                  []
# 2                                  []
# 3                                  []
# 4                                  []
# ...                               ...
# 176844                             []
# 176845                             []
# 176846                             []
# 176847                             []
# 176848                             []
#
#                                                    actors  \
# 0       [Takuya Kimura, Yûko Takeuchi, Kenji Sakaguchi...
# 1       [Brian O'Halloran, Jason Mewes, Jeff Anderson,...
# 2       [Katherine Jakeways, Anthony Mark Barrow, Stef...
# 3       [Jane Horrocks, Steven Mackintosh, Jodhi May, ...
# 4       [Sophie Cadieux, Paul Ahmarani, Antoine Vézina...
# ...                                                   ...
# 176844  [Ludovic Daxhelet, Sandrine Dans, Jean-Françoi...
# 176845                                       [Eric Bauza]
# 176846                                                 []
# 176847                                   [Ewout Genemans]
# 176848                                                 []
#
#                                           directors  \
# 0       [Kensaku Sawada, Isamu Nakae, Hirai Hideki]
# 1                                                []
# 2                                                []
# 3                                                []
# 4                                                []
# ...                                             ...
# 176844                                           []
# 176845                                           []
# 176846                                           []
# 176847                                           []
# 176848                                           []
#
#                                            background_url  \
# 0       http://image.tmdb.org/t/p/original/j8PrRaUPI19...
# 1       http://image.tmdb.org/t/p/original/7M0huD4pLqe...
# 2
# 3       http://image.tmdb.org/t/p/original/oJdDWkRNkdW...
# 4
# ...                                                   ...
# 176844  http://image.tmdb.org/t/p/original/ApZeLJuSqsy...
# 176845  http://image.tmdb.org/t/p/original/1TenNT3NAbc...
# 176846
# 176847  http://image.tmdb.org/t/p/original/2nKPBM20vLE...
# 176848
#
#                                                 image_url  \
# 0       http://image.tmdb.org/t/p/original/9Ub2BwnLYKo...
# 1       http://image.tmdb.org/t/p/original/xunXvzFlkf1...
# 2       http://image.tmdb.org/t/p/original/wK9h8FwbmOW...
# 3       http://image.tmdb.org/t/p/original/r2iyYZ98eN7...
# 4       http://image.tmdb.org/t/p/original/heOhqAyj2L6...
# ...                                                   ...
# 176844  http://image.tmdb.org/t/p/original/mbIUbI5npIp...
# 176845  http://image.tmdb.org/t/p/original/svXzRFIwmp2...
# 176846  http://image.tmdb.org/t/p/original/oAlGZNDDQTs...
# 176847
# 176848  http://image.tmdb.org/t/p/original/sRTAWTAXYD0...
#
#                                                   seasons  \
# 0       [{'season_number': 1, 'episodes': [{'title': '...
# 1       [{'season_number': 1, 'episodes': [{'title': '...
# 2       [{'season_number': 1, 'episodes': [{'title': '...
# 3       [{'season_number': 1, 'episodes': [{'title': '...
# 4       [{'season_number': 1, 'episodes': [{'title': '...
# ...                                                   ...
# 176844  [{'season_number': 1, 'episodes': [{'title': '...
# 176845  [{'season_number': 1, 'episodes': [{'title': '...
# 176846  [{'season_number': 1, 'episodes': [{'title': '...
# 176847  [{'season_number': 1, 'episodes': [{'title': '...
# 176848  [{'season_number': 1, 'episodes': [{'title': '...
#
#           first_aired.$date     last_aired.$date  first_aired  last_aired
# 0       2004-01-12T00:00:00  2004-03-22T00:00:00          NaN         NaN
# 1       2000-05-31T00:00:00  2002-12-22T00:00:00          NaN         NaN
# 2       2006-05-20T00:00:00  2006-06-24T00:00:00          NaN         NaN
# 3       2006-10-03T00:00:00  2006-11-07T00:00:00          NaN         NaN
# 4       2006-10-09T00:00:00  2006-11-13T00:00:00          NaN         NaN
# ...                     ...                  ...          ...         ...
# 176844  2022-10-15T00:00:00  2022-11-05T00:00:00          NaN         NaN
# 176845  2024-07-26T00:00:00  2024-07-27T00:00:00          NaN         NaN
# 176846  2024-06-26T00:00:00  2024-06-26T00:00:00          NaN         NaN
# 176847  2024-08-27T00:00:00                  NaN          NaN         NaN
# 176848  2020-04-17T00:00:00  2020-04-17T00:00:00          NaN         NaN
#
# [176849 rows x 17 columns]

# %%
df.tail()
# Out:
#             id                                              title  popularity  \
# 176844  260182        Nom d'un chien ! Le plus beau c'est le mien       0.680
# 176845  260183  Looney Tunes Presents: Sports Talk With Bugs B...       1.400
# 176846  260184                                              大汉的天空       1.021
# 176847  260185                                   Schiphol Airport       1.400
# 176848  260186                                       우당탕탕 하찮은 동창회       0.600
#
#                                                  overview             genres  \
# 176844                                                     [Reality, Family]
# 176845  Bugs Bunny meets his favorite athletes to lear...  [Animation, Talk]
# 176846                                                         [Documentary]
# 176847                                                                  None
# 176848  "The crazy reunion of friends who haven't seen...               None
#
#        language origin_country keywords  \
# 176844       fr           [BE]       []
# 176845       en           [US]       []
# 176846       zh           [CN]       []
# 176847       nl           [NL]       []
# 176848       ko           [KR]       []
#
#                                                    actors directors  \
# 176844  [Ludovic Daxhelet, Sandrine Dans, Jean-Françoi...        []
# 176845                                       [Eric Bauza]        []
# 176846                                                 []        []
# 176847                                   [Ewout Genemans]        []
# 176848                                                 []        []
#
#                                            background_url  \
# 176844  http://image.tmdb.org/t/p/original/ApZeLJuSqsy...
# 176845  http://image.tmdb.org/t/p/original/1TenNT3NAbc...
# 176846
# 176847  http://image.tmdb.org/t/p/original/2nKPBM20vLE...
# 176848
#
#                                                 image_url  \
# 176844  http://image.tmdb.org/t/p/original/mbIUbI5npIp...
# 176845  http://image.tmdb.org/t/p/original/svXzRFIwmp2...
# 176846  http://image.tmdb.org/t/p/original/oAlGZNDDQTs...
# 176847
# 176848  http://image.tmdb.org/t/p/original/sRTAWTAXYD0...
#
#                                                   seasons  \
# 176844  [{'season_number': 1, 'episodes': [{'title': '...
# 176845  [{'season_number': 1, 'episodes': [{'title': '...
# 176846  [{'season_number': 1, 'episodes': [{'title': '...
# 176847  [{'season_number': 1, 'episodes': [{'title': '...
# 176848  [{'season_number': 1, 'episodes': [{'title': '...
#
#           first_aired.$date     last_aired.$date  first_aired  last_aired
# 176844  2022-10-15T00:00:00  2022-11-05T00:00:00          NaN         NaN
# 176845  2024-07-26T00:00:00  2024-07-27T00:00:00          NaN         NaN
# 176846  2024-06-26T00:00:00  2024-06-26T00:00:00          NaN         NaN
# 176847  2024-08-27T00:00:00                  NaN          NaN         NaN
# 176848  2020-04-17T00:00:00  2020-04-17T00:00:00          NaN         NaN

# %%
features = ['title','genres','keywords','actors','directors','first_aired','language']

# %%
df['language'].isnull().values.any()
# Out:
# False

# %%
for feature in features:
    df[feature].fillna("", inplace=True)
# Out:
# <ipython-input-4-74c75922d7c6>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df[feature].fillna("", inplace=True)

# %%
def combine_features(row):
    title_weight = 0.5
    language_weight = 1.0
    first_aired_weight = 2.0
    genres_weight = 3.0
    keywords_weight = 3.0
    actors_weight = 3.0
    directors_weight = 2.0

    combined_features = (
        (row['title'] + " ") * int(title_weight * 10) +
        (row['language'] + " ") * int(language_weight * 10) +
        (row['first_aired'] + " ") * int(first_aired_weight * 10) +
        (row['genres'] + " ") * int(genres_weight * 10) +
        (row['keywords'] + " ") * int(keywords_weight * 10) +
        (row['actors'] + " ") * int(actors_weight * 10) +
        (row['directors'] + " ") * int(directors_weight * 10)
    )
    return combined_features

# %%
df = df.astype(str)
df['combined_features'] = df.apply(combine_features, axis = 1)

# %%
df.head()
# Out:
#           id                           title popularity  \
# 29667  32058  Great British Railway Journeys    997.411
# 36295  39297               Last Man Standing    994.219
# 71433  82873         The Kelly Clarkson Show    992.534
# 7371    7897              Cuéntame cómo pasó    992.233
# 2913    3051                   Lost in Space    991.052
#
#                                                 overview  \
# 29667  Michael Portillo takes to the tracks with a co...
# 36295  A married father of three tries to maintain hi...
# 71433  Kelly Clarkson presents the biggest newsmakers...
# 7371   Recounts the experiences of a middle-class fam...
# 2913   The space family Robinson is sent on a five-ye...
#
#                                genres language origin_country  \
# 29667                 ['Documentary']       en         ['GB']
# 36295                      ['Comedy']       en         ['US']
# 71433                        ['Talk']       en         ['US']
# 7371              ['Comedy', 'Drama']       es         ['ES']
# 2913   ['Sci-Fi & Fantasy', 'Comedy']       en         ['US']
#
#                                                 keywords  \
# 29667                                       ['railroad']
# 36295  ['marketing', 'family', 'sitcom', 'family come...
# 71433                            ['talk show', 'singer']
# 7371   ['spain', 'madrid, spain', 'dictatorship', 'fa...
# 2913   ['spacecraft', 'future', 'space', 'alien planet']
#
#                                                   actors        directors  \
# 29667                               ['Michael Portillo']  ['Ben Rowland']
# 36295  ['Tim Allen', 'Nancy Travis', 'Hector Elizondo...               []
# 71433                                 ['Kelly Clarkson']               []
# 7371   ['Imanol Arias', 'Ana Duato', 'María Galiana',...               []
# 2913   ['Guy Williams', 'June Lockhart', 'Mark Goddar...               []
#
#                                           background_url  \
# 29667  http://image.tmdb.org/t/p/original/zetjn4dAGs3...
# 36295  http://image.tmdb.org/t/p/original/3xU0vpr9QJY...
# 71433  http://image.tmdb.org/t/p/original/6BGQ39cH2hf...
# 7371   http://image.tmdb.org/t/p/original/gS67p2XWTpg...
# 2913   http://image.tmdb.org/t/p/original/upqfQF1LBPf...
#
#                                                image_url  \
# 29667  http://image.tmdb.org/t/p/original/h9XrDjo4y8W...
# 36295  http://image.tmdb.org/t/p/original/ofUvbcwxcA0...
# 71433  http://image.tmdb.org/t/p/original/9Gg1oM8Us8g...
# 7371   http://image.tmdb.org/t/p/original/1OjgVLawOZz...
# 2913   http://image.tmdb.org/t/p/original/dGhtCpYZutu...
#
#                                                  seasons    first_aired.$date  \
# 29667  [{'season_number': 1, 'episodes': [{'title': '...  2010-01-04T00:00:00
# 36295  [{'season_number': 1, 'episodes': [{'title': '...  2011-10-11T00:00:00
# 71433  [{'season_number': 1, 'episodes': [{'title': '...  2019-09-09T00:00:00
# 7371   [{'season_number': 1, 'episodes': [{'title': '...  2001-09-13T00:00:00
# 2913   [{'season_number': 1, 'episodes': [{'title': '...  1965-09-15T00:00:00
#
#           last_aired.$date first_aired last_aired  \
# 29667  2024-04-05T00:00:00                    nan
# 36295  2021-05-20T00:00:00                    nan
# 71433  2024-06-21T00:00:00                    nan
# 7371   2023-11-29T00:00:00                    nan
# 2913   1968-03-06T00:00:00                    nan
#
#                                        combined_features  index2
# 29667  Great British Railway Journeys Great British R...       0
# 36295  Last Man Standing Last Man Standing Last Man S...       1
# 71433  The Kelly Clarkson Show The Kelly Clarkson Sho...       2
# 7371   Cuéntame cómo pasó Cuéntame cómo pasó Cuéntame...       3
# 2913   Lost in Space Lost in Space Lost in Space Lost...       4

# %%
df = df.sort_values(by=['popularity'], ascending=False)

df = df[:50000]

df['index2'] = range(0, len(df))

# %%
print(df.columns.values)
# Out:
# ['id' 'title' 'popularity' 'overview' 'genres' 'language' 'origin_country'
#  'keywords' 'actors' 'directors' 'background_url' 'image_url' 'seasons'
#  'first_aired.$date' 'last_aired.$date' 'first_aired' 'last_aired'
#  'combined_features' 'index2']

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix)
print(cosine_sim.shape)
# Out:
# (50000, 50000)

# %%
def get_title_from_index(index):
    return df[df.index2 == index]["title"].values[0]
def get_index_from_title(title):
    return df[df.title == title]["index2"].values[0]
def get_id_from_index(index2):
    return df[df.index2==index2]["id"].values[0]

# %%
tv_user_likes = "Lost in Space"
tv_index = get_index_from_title(tv_user_likes)
#print(cosine_sim[0])
similar_tvs = list(enumerate(cosine_sim[tv_index])) #accessing the row corresponding to given movie to find all the similarity scores for that movie and then enumerating over it
print(similar_tvs)
# Out:
# [(0, 0.0007917667976621143), (1, 0.011134782752442727), (2, 0.0007129244821236228), (3, 0.0038607145957263314), (4, 1.0000000000000004), (5, 0.05048278852036599), (6, 0.0077035187639989495), (7, 0.0), (8, 0.0), (9, 0.006483219100920593), (10, 0.004002777178961475), (11, 0.01533249710046999), (12, 0.0), (13, 0.01058885628408386), (14, 0.006492588099201234), (15, 0.02579632763673247), (16, 0.003699195247461184), (17, 0.0), (18, 0.0), (19, 0.006542782541299322), (20, 0.0052338655850944025), (21, 0.013826522458047245), (22, 0.04009958247368121), (23, 0.028613993965299882), (24, 0.0), (25, 0.03344668769352769), (26, 0.0016667321604049575), (27, 0.009684521207440676), (28, 0.006034772191860992), (29, 0.006032094854334051), (30, 0.0), (31, 0.0025387686264909167), (32, 0.0), (33, 0.0), (34, 0.0003780176014374229), (35, 0.00598335647665132), (36, 0.005707479666131581), (37, 0.0002583103801556059), (38, 0.0), (39, 0.0), (40, 0.0034430148186959573), (41, 0.0002985525447889906), (42, 0.0), (43, 0.048868861737448116), (44, 0.044663997916913056), (45, 0.0), (46, 0.026207054456123684), (47, 0.00038877058688899604), (48, 0.0), (49, 0.0043482033701466825), (50, 0.004405744530361667), (51, 0.0005585842960609351), (52, 0.0), (53, 0.0030139320553102273), (54, 0.0), (55, 0.0003083163275667642), (56, 0.00017615837435425822), (57, 0.0), (58, 0.0), (59, 0.0), (60, 0.0006300915180849561), (61, 0.0257324647579438), (62, 0.04635741625276685), (63, 0.0106267551192599), (64, 0.0032332468958888804), (65, 0.00398763165917582), (66, 0.0), (67, 0.01839557660539169), (68, 0.0006445284318725347), (69, 0.0010836436361440136), (70, 0.0), (71, 0.0), (72, 0.03768937206989033), (73, 0.0), (74, 0.05481446079970948), (75, 0.00029368219516761517), (76, 0.0), (77, 0.0), (78, 0.016004582806396717), (79, 0.0), (80, 0.03752495927185097), (81, 0.0), (82, 0.00670353502406752), (83, 0.028651276229851468), (84, 0.0), (85, 0.0), (86, 0.03114125316410664), (87, 0.02460131575564426), (88, 0.0), (89, 0.0017328102960578917), (90, 0.0), (91, 0.004130689375187073), (92, 0.0008597868114703673
    i=i+1
    if i>50:
        break
# Out:
# Top 50 similar tvs to Lost in Space are:
#
# Far Out Space Nuts
# 3042
# Star Trek: Voyager
# 1855
# Dans une galaxie près de chez vous
# 13706
# The Expanse
# 63639
# Space Precinct
# 3129
# TVography
# 36768
# Star Trek: Enterprise
# 314
# Born Naughty?
# 222317
# Mark Williams' Big Bangs
# 28857
# Aurora
# 203144
# Mysteries of the Universe: Our Solar System
# 109312
# Red Planet
# 16910
# Futurama
# 615
# Ｖ
# 243072
# Other Space
# 62383
# The Changes
# 9498
# Star Trek: Deep Space Nine
# 580
# 白狐的人生
# 95421
# 特派幸福
# 118983
# Star Wars Blips
# 105106
# Duck Dodgers
# 216
# Babylon 5
# 3137
# Something Wicked
# 248350
# The Fantastic Four
# 2373
# Alien Highway
# 90278
# Bobcat Goldthwait's Misfits & Monsters
# 80286
# The Planets
# 6335
# Star Trek
# 253
# Haunted USA
# 123853
# Earth 2
# 1473
# The Whistler
# 22851
# Silent Eye
# 117346
# Under the Skin
# 116325
# Captain Disillusion
# 221726
# UFO
# 2560
# Stranger in a Strange Land
# 71911
# 跨越千年来爱你
# 246554
# Tales of the Tardis
# 238486
# A Thousand Suns
# 251882
# Trisha Goddard
# 359
# Troopers: Animated
# 245017
# Battlestar Galactica: Blood & Chrome
# 33240
# 美少女遊撃隊バトルスキッパー
# 96292
# Beasts
# 5204
# Űrgammák
# 61715
# Meet By Window
# 116360
# Torchy the Battery Boy
# 4338
# Worlds Beyond
# 29855
# The Strangerers
# 12077
# Peabody's Improbable History
# 75489
# Bedtime Stories
# 29543

# %%
# Dictionary to store movie ID and top 50 similar movie IDs
similar_tvs_dict = {}
i = 0
# Find top 50 similar movies for each movie
for index, row in df.iterrows():
    tv_id = row['id']
    tv_index = int(row['index2'])
    similar_tvs = list(enumerate(cosine_sim[tv_index]))
    sorted_similar_tvs= sorted(similar_tvs, key=lambda x: x[1], reverse=True)[1:51]
    similar_tv_ids = [get_id_from_index(element[0]) for element in sorted_similar_tvs]
    similar_tvs_dict[tv_id] = similar_tv_ids
    print(similar_tv_ids)
    if i == 5:
      break
    i+=1

    if tv_index%1000 == 0:
      print(tv_index)

# Save the dictionary as a JSON file
json_file_path = '/content/drive/My Drive/similar_tvs.json'
with open(json_file_path, 'w') as json_file:
    json.dump(similar_tvs_dict, json_file)

print(f"Top 50 similar tvs for each movie saved to {json_file_path}")
# Out:
# ['251852', '157259', '102509', '156342', '73785', '93408', '37287', '74542', '15857', '76745', '18438', '128430', '58535', '111836', '92224', '195687', '195678', '64629', '194592', '87406', '86523', '85472', '65081', '30872', '17431', '130234', '194574', '195680', '20979', '195689', '216195', '157197', '98730', '117242', '18624', '4994', '195677', '255407', '135821', '14140', '137846', '105256', '235834', '215408', '52498', '73543', '109536', '47888', '100159', '229240']
# 0
# ['3791', '46796', '26690', '93470', '214620', '93708', '83038', '92172', '233351', '208063', '1146', '118733', '212999', '207136', '7995', '107422', '97193', '3392', '209941', '24137', '81841', '83136', '214720', '68345', '12403', '24401', '82679', '87296', '11618', '649', '46410', '100008', '10447', '20810', '70089', '25219', '14729', '225875', '595', '98770', '109056', '93670', '108971', '237391', '122438', '41633', '79786', '91701', '72592', '61714']
# ['213512', '59021', '70890', '26422', '212853', '42576', '64189', '36132', '75499', '96592', '24066', '252989', '7962', '27781', '226001', '223619', '107271', '80658', '11869', '118452', '16180', '24296', '201453', '101170', '67955', '129402', '71857', '103812', '238439', '155698', '253672', '112261', '250488', '133872', '104197', '113445', '82158', '135384', '253103', '122883', '104309', '64536', '27469', '28195', '121058', '21939', '137463', '103108', '120097', '134684']
# ['119732', '90074', '85772', '118491', '62841', '82768', '256422', '96636', '61872', '89549', '79082', '220449', '11773', '218428', '43405', '77117', '69057', '118099', '86201', '137813', '251641', '86175', '83256', '101069', '980', '38276', '105904', '217099', '236873', '129679', '224512', '99565', '83038', '95601', '103394', '245250', '63103', '73980', '37737', '154457', '62453', '22489', '78148', '76303', '230963', '231681', '44506', '115502', '72239', '76497']
# ['3042', '1855', '13706', '63639', '3129', '36768', '314', '222317', '28857', '203144', '109312', '16910', '615', '243072', '62383', '9498', '580', '95421', '118983', '105106', '216', '3137', '248350', '2373', '90278', '80286', '6335', '253', '123853', '1473', '22851', '117346', '116325', '221726', '2560', '71911', '246554', '238486', '251882', '359', '245017', '33240', '96292', '5204', '61715', '116360', '4338', '29855', '12077', '75489']
# ['138502', '79936', '243622', '252317', '47823', '115867', '237421', '105944', '118355', '223762', '211442', '105907', '88639', '104926', '78239', '234897', '6029', '95244', '125727', '236009', '244891', '33623', '34946', '78231', '113125', '11877', '96121', '1130', '85188', '123976', '108892', '75486', '248357', '68888', '249907', '220048', '219548', '95557', '58142', '15743', '57967', '55371', '73639', '8721', '236034', '236534', '115547', '115058', '79635', '230108']
# Top 50 similar tvs for each movie saved to /content/drive/My Drive/similar_tvs.json

# %%
# Convert DataFrame to the desired format
df = pd.DataFrame(similar_tvs_dict)
df_melted2 = df.melt(var_name='ID', value_name='similar_tvshows')

# Display the DataFrame
print(df_melted2.head())

# Convert DataFrame to list of dictionaries (JSON documents)
similar_tvs_dict = df_melted2.to_dict(orient='records')

# Save the dictionary as a JSON file
json_file_path = '/content/drive/My Drive/similar_tvs.json'
with open(json_file_path, 'w') as json_file:
    json.dump(similar_tvs_dict, json_file, indent=2)
# Out:
#       ID similar_tvshows
# 0  32058          251852
# 1  32058          157259
# 2  32058          102509
# 3  32058          156342
# 4  32058           73785

# %%
import json

# Load the original JSON file
with open('/content/drive/My Drive/similar_tvs (1).json', 'r') as json_file:
    similar_tvs_dict = json.load(json_file)

# Convert to the desired format
formatted_data = [
    {
        "_id": key,
        "similar_content": value
    } for key, value in similar_tvs_dict.items()
]

# Save the formatted data to a new JSON file
with open('/content/drive/My Drive/formatted_similar_tvs.json', 'w') as json_file:
    json.dump(formatted_data, json_file, indent=4)
